# %%
import pandas as pd
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_top_book_lists")
print(len(df))
# Out:
# 3

# %%
df=df[1]

# %%
df
# Out:
#                          Publisher  \
# 0   Citadelby Martin Seymour-Smith
# 1       Crime Writers' Association
# 2   Grafton Books by David Pringle
# 3                  Larry McCaffery
# 4                         Le Monde
# 5                   Modern Library
# 6                   Modern Library
# 7       Mystery Writers of America
# 8       New York Times Book Review
# 9              Norwegian Book Club
# 10               Nimbus Publishing
# 11                 Tidningen Boken
# 12                            Time
# 13                    The Guardian
# 14                  Shūkan Bunshun
# 15         Xanadu by David Pringle
#
#                                                  Name   Published
# 0         The 100 Most Influential Books Ever Written        1998
# 1                The Top 100 Crime Novels of All Time        1990
# 2                 Modern Fantasy: The 100 Best Novels        1988
# 3   20th Century's Greatest Hits: 100 English-Lang...        1999
# ...

# %%
df.to_csv('List_of_top_book_lists.xlsx', index=False)
