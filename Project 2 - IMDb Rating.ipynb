# %%
import pandas as pd
df=pd.read_html('https://www.imdb.com/chart/top')
len(df)
# Out:
# 1

# %%
df=df[0]

# %%
df['Rank & Title']=df['Rank & Title'].str.strip(')')
df['Rank']=df['Rank & Title'].str.split('.').str[0]
df['Year']=df['Rank & Title'].str.split('(').str[1]
df['Rank and Title']=df['Rank & Title'].str.split('(').str[0]
df['Title']=df['Rank and Title'].str.split('.').str[1]
df
# Out:
#      Unnamed: 0                         Rank & Title  IMDb Rating  \
# 0           NaN  1.  The Shawshank Redemption  (1994          9.2
# 1           NaN             2.  The Godfather  (1972          9.2
# 2           NaN           3.  The Dark Knight  (2008          9.0
# 3           NaN    4.  The Godfather: Part II  (1974          9.0
# 4           NaN              5.  12 Angry Men  (1957          8.9
# ..          ...                                  ...          ...
# 245         NaN                 246.  Aladdin  (1992          8.0
# 246         NaN                  247.  Gandhi  (1982          8.0
# 247         NaN                248.  Jai Bhim  (2021          8.0
# 248         NaN                249.  The Help  (2011          8.0
# 249         NaN    250.  Beauty and the Beast  (1991          8.0
#
#                             Your Rating  Unnamed: 4 Rank  Year  \
# 0    12345678910 NOT YET RELEASED  Seen         NaN    1  1994
# ...

# %%
df=df.drop(['Unnamed: 0','Rank & Title','Your Rating','Unnamed: 4'],axis=1)

# %%
df=df[['Rank','Title','Year','IMDb Rating']]

# %%
df.head()
# Out:
#   Rank                         Title  Year  IMDb Rating
# 0    1    The Shawshank Redemption    1994          9.2
# 1    2               The Godfather    1972          9.2
# 2    3             The Dark Knight    2008          9.0
# 3    4      The Godfather: Part II    1974          9.0
# 4    5                12 Angry Men    1957          8.9

# %%
df.to_csv('IMDb Rating.csv',index=False)
